# %%
# %run Comparison_heuristic_algorithm.py
# Out:
# 检测到 40 个任务文件，准备开始计算...
# --------------------------------------------------
# [1/40] 完成: gen_100_job_0.json -> Makespan: 821
# [2/40] 完成: gen_100_job_1.json -> Makespan: 804
# [3/40] 完成: gen_100_job_2.json -> Makespan: 784
# [4/40] 完成: gen_100_job_3.json -> Makespan: 802
# [5/40] 完成: gen_100_job_4.json -> Makespan: 734
# [6/40] 完成: gen_100_job_5.json -> Makespan: 798
# [7/40] 完成: gen_100_job_6.json -> Makespan: 839
# [8/40] 完成: gen_100_job_7.json -> Makespan: 810
# [9/40] 完成: gen_100_job_8.json -> Makespan: 836
# [10/40] 完成: gen_100_job_9.json -> Makespan: 864
# [11/40] 完成: gen_10_job_0.json -> Makespan: 193
# [12/40] 完成: gen_10_job_1.json -> Makespan: 151
# [13/40] 完成: gen_10_job_2.json -> Makespan: 146
# [14/40] 完成: gen_10_job_3.json -> Makespan: 143
# [15/40] 完成: gen_10_job_4.json -> Makespan: 143
# [16/40] 完成: gen_10_job_5.json -> Makespan: 155
# [17/40] 完成: gen_10_job_6.json -> Makespan: 159
# [18/40] 完成: gen_10_job_7.json -> Makespan: 144
# ...
